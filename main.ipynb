# %% [markdown]
# # Rendered Figures Only
#
# This notebook is intentionally static: no long-running code cells.
# Open it to view the figures directly.
#
# ## Figure 4 (Experiment 1)
# ![Figure 4 (Experiment 1)](attachment:experiment1_fig4.png)
#
# ## Figure 5(a), N=4 (Experiment 2)
# ![Figure 5(a), N=4 (Experiment 2)](attachment:experiment2_fig5a_n4.png)
#
# ## Figure 5(b), N=5 (Experiment 2)
# ![Figure 5(b), N=5 (Experiment 2)](attachment:experiment2_fig5b_n5.png)
#
# ## Figure 6 (Experiment 3)
# ![Figure 6 (Experiment 3)](attachment:experiment3_fig6.png)
